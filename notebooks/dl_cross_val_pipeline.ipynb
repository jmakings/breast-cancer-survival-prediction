# %%
# load libraries
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from lifelines.utils import concordance_index

import pyhere as here
import random
import copy

from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %% [markdown]
# # Data Loading and Initial Processing

# %%
# ============================================================
# CLINICAL + MUTATION FEATURE BUILDER
# ============================================================

class ClinicalMutationBuilder:
    """
    Builds X_clin from:
      - clinical metadata
      - mutation features (binary + severity + TMB)
    """

    def __init__(self):
        self.cat_encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
        self.num_imputer = SimpleImputer(strategy="median")

        self.fitted = False
        self.feature_names = None

    # -----------------------------
    # FIT
    # -----------------------------
    def fit(self, clinical_df, mutation_df):
        """
        Fit encoders ONLY on training data (CV-safe)
        """

        clinical_df = clinical_df.copy()
        mutation_df = mutation_df.copy()

        # -----------------------------
        # 1. Identify feature types
        # -----------------------------
        cat_cols = clinical_df.select_dtypes(include=["object", "category"]).columns
        num_cols = clinical_df.select_dtypes(include=["int64", "float64"]).columns

        self.cat_cols = list(cat_cols)
        self.num_cols = list(num_cols)

        # -----------------------------
        # 2. Fit encoders
        # -----------------------------
        if len(self.cat_cols) > 0:
            self.cat_encoder.fit(clinical_df[self.cat_cols])

        if len(self.num_cols) > 0:
            self.num_imputer.fit(clinical_df[self.num_cols])

        # -----------------------------
        # 3. Mutation schema sanity check
        # -----------------------------
        expected_mut_cols = mutation_df.shape[1]
        self.mutation_dim = expected_mut_cols

        self.fitted = True
        return self

    # -----------------------------
    # TRANSFORM
    # -----------------------------
    def transform(self, clinical_df, mutation_df):
        assert self.fitted, "Must call fit() first"

        clinical_df = clinical_df.copy()
        mutation_df = mutation_df.copy()

        # -----------------------------
        # 1. Clinical numeric
        # -----------------------------
        if len(self.num_cols) > 0:
            clin_num = self.num_imputer.transform(clinical_df[self.num_cols])
        else:
            clin_num = np.zeros((len(clinical_df), 0))

        # -----------------------------
        # 2. Clinical categorical
        # -----------------------------
        if len(self.cat_cols) > 0:
            clin_cat = self.cat_encoder.transform(clinical_df[self.cat_cols])
        else:
            clin_cat = np.zeros((len(clinical_df), 0))

        # -----------------------------
        # 3. Mutation handling
        # -----------------------------
        mut = mutation_df.values.astype(np.float32)

        # Replace NaNs / infs in mutation data
        mut = np.nan_to_num(mut, nan=0.0, posinf=0.0, neginf=0.0)

        # IMPORTANT: do NOT standardize mutation features
        # (keeps binary sparsity intact)

        # -----------------------------
        # 4. Concatenate all clinical + mutation
        # -----------------------------
        X_clin = np.hstack([clin_num, clin_cat, mut])

        # -----------------------------
        # 5. Final safety check
        # -----------------------------
        X_clin = np.nan_to_num(X_clin, nan=0.0, posinf=0.0, neginf=0.0)

        return X_clin

# %%
# ============================================================
# GLOBAL FEATURE CLEANER (RECOMMENDED BEFORE CV)
# ============================================================

def remove_constant_features(X, threshold=1e-8):
    """
    Removes zero-variance / near-zero variance features.
    CRITICAL for preventing StandardScaler NaNs.
    """

    var = X.var(axis=0)
    keep = var > threshold

    X_clean = X[:, keep]

    print(f"[Feature Filter]")
    print(f"Original: {X.shape[1]} features")
    print(f"Kept: {X_clean.shape[1]} features")
    print(f"Dropped: {np.sum(~keep)} constant features")

    return X_clean, keep

# %%
# ============================================================
# OPTIONAL: SAFE MUTATION BUILDER (if you have raw mutation tables)
# ============================================================

def build_mutation_matrix(mut_binary_df, mut_severity_df=None, tmb_series=None):
    """
    Constructs mutation feature matrix safely.
    """

    mut_binary = mut_binary_df.values.astype(np.float32)
    mut_binary = np.nan_to_num(mut_binary)
    
    features = [mut_binary]

    if mut_severity_df is not None:
        mut_sev = mut_severity_df.values.astype(np.float32)
        mut_sev = np.log1p(np.nan_to_num(mut_sev))
        features.append(mut_sev)

    if tmb_series is not None:
        tmb = np.log1p(np.nan_to_num(tmb_series.values.astype(np.float32))).reshape(-1, 1)
        features.append(tmb)

    X_mut = np.hstack(features)

    return X_mut

# %%
def create_X_clin_pipeline(clinical_df, mutation_df, y_event):
    """
    Full safe pipeline to create X_clin
    """

    # -----------------------------
    # 1. Build raw matrix
    # -----------------------------
    builder = ClinicalMutationBuilder()

    builder.fit(clinical_df, mutation_df)

    X_clin = builder.transform(clinical_df, mutation_df)

    # -----------------------------
    # 2. Remove constant features globally
    # -----------------------------
    X_clin, keep_mask = remove_constant_features(X_clin)

    # -----------------------------
    # 3. Final safety cleanup
    # -----------------------------
    X_clin = np.nan_to_num(X_clin, nan=0.0, posinf=0.0, neginf=0.0)

    print("\nFinal X_clin shape:", X_clin.shape)

    return X_clin, builder, keep_mask

# %%
# ============================================================
# COX LOSS (STABLE)
# ============================================================
def cox_loss(risk_scores, times, events):
    order = torch.argsort(times, descending=True)

    risk_scores = risk_scores[order]
    events = events[order]

    log_cumsum = torch.logcumsumexp(risk_scores, dim=0)

    loss = -torch.sum((risk_scores - log_cumsum) * events)

    n_events = events.sum().clamp_min(1.0)

    return loss / n_events

# %%
from lifelines import CoxPHFitter
import pandas as pd
import numpy as np

# ============================================================
# Univariate Cox Gene Selector
# ============================================================

def select_survival_genes(X_expr, y_time, y_event,
                          top_k=100,
                          min_variance=1e-8):

    if isinstance(X_expr, pd.DataFrame):
        gene_names = X_expr.columns.to_numpy()
        X_expr = X_expr.to_numpy()
    else:
        gene_names = np.arange(X_expr.shape[1])

    y_time = np.asarray(y_time)
    y_event = np.asarray(y_event)

    n_genes = X_expr.shape[1]
    pvals = np.ones(n_genes)

    for i in range(n_genes):

        gene = X_expr[:, i]

        if np.var(gene) < min_variance:
            continue

        df = pd.DataFrame({
            "time": y_time,
            "event": y_event,
            "gene": gene
        })

        try:
            cph = CoxPHFitter(penalizer=0.01)
            cph.fit(df,
                    duration_col="time",
                    event_col="event")

            pvals[i] = cph.summary.loc["gene", "p"]

        except Exception:
            pvals[i] = 1.0

    selected_idx = np.argsort(pvals)[:top_k]
    selected_genes = gene_names[selected_idx]

    return selected_idx, selected_genes

# %%
# ============================================================
# Faster Gene Selector Function
# ============================================================
def select_survival_genes_fast(
    X_expr,
    y_time,
    y_event,
    top_k=100
):

    if isinstance(X_expr, pd.DataFrame):
        gene_names = X_expr.columns.to_numpy()
        X_expr = X_expr.to_numpy()
    else:
        gene_names = np.arange(X_expr.shape[1])

    X = np.asarray(X_expr, dtype=np.float64)
    times = np.asarray(y_time)
    events = np.asarray(y_event)

    # Sort by time
    order = np.argsort(times)

    X = X[order]
    events = events[order]

    # Risk set means
    rev_cumsum = np.cumsum(X[::-1], axis=0)[::-1]

    risk_counts = np.arange(len(X), 0, -1)

    risk_means = rev_cumsum / risk_counts[:, None]

    # Score statistics
    event_mask = events == 1

    U = np.sum(
        X[event_mask] - risk_means[event_mask],
        axis=0
    )

    scores = np.abs(U)

    selected_idx = np.argsort(scores)[::-1][:top_k]

    selected_genes = gene_names[selected_idx]

    return selected_idx, selected_genes, scores[selected_idx]

# %%
# ============================================================
# PREPROCESSOR (LEAKAGE SAFE)
# ============================================================
class SurvivalPreprocessor:
    def __init__(self):
        self.scaler_clin = StandardScaler()
        self.scaler_expr = StandardScaler()
        self.is_fitted = False

    def fit(self, X_clin, X_expr):
        self.scaler_clin.fit(X_clin)
        self.scaler_expr.fit(X_expr)
        self.is_fitted = True

    def transform(self, X_clin, X_expr):
        assert self.is_fitted

        X_clin = self.scaler_clin.transform(X_clin)
        X_expr = self.scaler_expr.transform(X_expr)

        X_clin = np.nan_to_num(X_clin, nan=0.0, posinf=0.0, neginf=0.0)
        X_expr = np.nan_to_num(X_expr, nan=0.0, posinf=0.0, neginf=0.0)

        return X_clin, X_expr

# %%
# ============================================================
# SURVIVAL AWARE AUTOENCODER
# ============================================================
class SurvivalAwareAutoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim=64):
        super().__init__()

        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(128, latent_dim),
            nn.ReLU()
        )

        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Linear(256, input_dim)
        )

        self.survival_head = nn.Linear(latent_dim, 1)

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        risk = self.survival_head(z).squeeze(-1)
        return x_recon, z, risk

# %%
# ============================================================
# DUAL ENCODER SURVIVAL MODEL
# ============================================================
class DualEncoderSurvivalNet(nn.Module):
    def __init__(self, clin_mut_dim, expr_autoencoder,
                 latent_dim_clin=32, latent_dim_expr=64):

        super().__init__()

        self.clin_mut_enc = nn.Sequential(
            nn.Linear(clin_mut_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(64, latent_dim_clin),
            nn.ReLU()
        )

        self.expr_enc = expr_autoencoder

        fusion_dim = latent_dim_clin + latent_dim_expr

        self.fusion = nn.Sequential(
            nn.Linear(fusion_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(32, 1)
        )

    def forward(self, x_clin, x_expr):
        z_clin = self.clin_mut_enc(x_clin)
        z_expr = self.expr_enc(x_expr)[1]

        z = torch.cat([z_clin, z_expr], dim=1)
        risk = self.fusion(z).squeeze(-1)

        return risk

# %%
# ============================================================
# AUTOENCODER TRAINING (PER FOLD)
# ============================================================
def train_survival_autoencoder(X_expr, y_time, y_event,
                               latent_dim=64, epochs=200):

    input_dim = X_expr.shape[1]
    ae = SurvivalAwareAutoencoder(input_dim, latent_dim)

    optimizer = optim.Adam(ae.parameters(), lr=1e-3, weight_decay=1e-4)
    recon_fn = nn.MSELoss()

    X_expr = X_expr.float()
    y_time = y_time.float()
    y_event = y_event.float()

    best_loss = float("inf")
    best_weights = copy.deepcopy(ae.state_dict())

    for epoch in range(epochs):
        ae.train()
        optimizer.zero_grad()

        recon, z, risk = ae(X_expr)

        recon_loss = recon_fn(recon, X_expr)
        surv_loss = cox_loss(risk, y_time, y_event)

        loss = recon_loss + 0.05 * surv_loss

        loss.backward()
        optimizer.step()

        if loss.item() < best_loss:
            best_loss = loss.item()
            best_weights = copy.deepcopy(ae.state_dict())

    ae.load_state_dict(best_weights)
    return ae

# %%
# ============================================================
# TRAIN DUAL ENCODER
# ============================================================
def train_dual_encoder_survival_net(X_clin, X_expr, y_time, y_event,
                                   expr_autoencoder,
                                   latent_dim_clin=32,
                                   latent_dim_expr=64,
                                   epochs=500):

    model = DualEncoderSurvivalNet(
        clin_mut_dim=X_clin.shape[1],
        expr_autoencoder=expr_autoencoder,
        latent_dim_clin=latent_dim_clin, 
        latent_dim_expr=latent_dim_expr
    )

    X_clin = X_clin.float()
    X_expr = X_expr.float()
    y_time = y_time.float()
    y_event = y_event.float()

    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-3)

    best_loss = float("inf")
    best_weights = copy.deepcopy(model.state_dict())

    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()

        risk = model(X_clin, X_expr)
        loss = cox_loss(risk, y_time, y_event)

        loss.backward()
        optimizer.step()

        if loss.item() < best_loss:
            best_loss = loss.item()
            best_weights = copy.deepcopy(model.state_dict())

    model.load_state_dict(best_weights)
    return model

# %%
# ============================================================
# C-INDEX
# ============================================================
def compute_cindex(model, times, events, X_clin, X_expr):
    model.eval()
    with torch.no_grad():
        risk = model(X_clin, X_expr).cpu().numpy()

    return concordance_index(times, -risk, events)

# %%
def run_pipeline(clinical_df, mutation_df, X_expr, y_time, y_event, k=100, latent_dim_clin=32, latent_dim_expr=64, random_state=42):

    # ============================================================
    # 1. HOLDOUT SPLIT (NO LEAKAGE)
    # ============================================================
    idx = np.arange(len(y_event))

    train_idx, test_idx = train_test_split(
        idx,
        test_size=0.2,
        stratify=y_event,
        random_state=random_state
    )

    clinical_train, clinical_test = clinical_df.iloc[train_idx], clinical_df.iloc[test_idx]
    mutation_train, mutation_test = mutation_df.iloc[train_idx], mutation_df.iloc[test_idx]

    expr_train, expr_test = X_expr.iloc[train_idx], X_expr.iloc[test_idx]

    y_time_train, y_time_test = y_time[train_idx], y_time[test_idx]
    y_event_train, y_event_test = y_event[train_idx], y_event[test_idx]

    # ============================================================
    # 2. CV SETUP
    # ============================================================
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)

    cv_scores = []

    for fold, (tr, va) in enumerate(skf.split(clinical_train, y_event_train)):

        print(f"\n================ FOLD {fold+1} ================")

        # -------------------------
        # Split fold data
        # -------------------------
        clin_tr = clinical_train.iloc[tr]
        clin_va = clinical_train.iloc[va]

        mut_tr = mutation_train.iloc[tr]
        mut_va = mutation_train.iloc[va]

        expr_tr = expr_train.iloc[tr]
        expr_va = expr_train.iloc[va]

        yt_tr = y_time_train[tr]
        yt_va = y_time_train[va]

        ye_tr = y_event_train[tr]
        ye_va = y_event_train[va]

        # ==================================================
        # SURVIVAL-BASED GENE FILTERING
        # ==================================================

        gene_idx, selected_genes, scores = select_survival_genes_fast(
            expr_tr,
            yt_tr,
            ye_tr,
            top_k=k
        )

        expr_tr = expr_tr.iloc[:, gene_idx]
        expr_va = expr_va.iloc[:, gene_idx]

        print(f"Selected {len(gene_idx)} genes")
        print("Top genes:")
        print(selected_genes[:10])

        # ============================================================
        # 3. BUILD X_CLIN (LEAKAGE SAFE: FIT INSIDE FOLD)
        # ============================================================
        builder = ClinicalMutationBuilder()

        builder.fit(clin_tr, mut_tr)

        Xc_tr = builder.transform(clin_tr, mut_tr)
        Xc_va = builder.transform(clin_va, mut_va)

        # ============================================================
        # 4. FEATURE CLEANING (IMPORTANT)
        # ============================================================
        Xc_tr, keep = remove_constant_features(Xc_tr)
        Xc_va = Xc_va[:, keep]

        # ============================================================
        # 5. PREPROCESS EXPRESSIONS (FOLD SAFE)
        # ============================================================
        pre = SurvivalPreprocessor()
        pre.fit(Xc_tr, expr_tr)

        Xc_tr, Xe_tr = pre.transform(Xc_tr, expr_tr)
        Xc_va, Xe_va = pre.transform(Xc_va, expr_va)

        # ============================================================
        # 6. TENSORS
        # ============================================================
        Xc_tr = torch.tensor(Xc_tr).float()
        Xe_tr = torch.tensor(Xe_tr).float()
        yt_tr = torch.tensor(yt_tr).float()
        ye_tr = torch.tensor(ye_tr).float()

        Xc_va = torch.tensor(Xc_va).float()
        Xe_va = torch.tensor(Xe_va).float()

        # ============================================================
        # 7. AUTOENCODER (PER FOLD)
        # ============================================================
        ae = train_survival_autoencoder(Xe_tr, yt_tr, ye_tr, latent_dim=latent_dim_expr)

        # ============================================================
        # 8. DUAL ENCODER MODEL
        # ============================================================
        model = train_dual_encoder_survival_net(
            Xc_tr, Xe_tr, yt_tr, ye_tr, ae, 
            latent_dim_clin=latent_dim_clin, 
            latent_dim_expr=latent_dim_expr
        )

        # ============================================================
        # 9. EVALUATION
        # ============================================================
        cindex = compute_cindex(model, yt_va, ye_va, Xc_va, Xe_va)

        cv_scores.append(cindex)

        print("C-index:", cindex)

    # ============================================================
    # 10. FINAL TRAINING (FULL TRAIN SET)
    # ============================================================
    print("\n================ FINAL TRAINING ================")

    builder = ClinicalMutationBuilder()
    builder.fit(clinical_train, mutation_train)

    Xc_train = builder.transform(clinical_train, mutation_train)
    Xc_test = builder.transform(clinical_test, mutation_test)

    Xc_train, keep = remove_constant_features(Xc_train)
    Xc_test = Xc_test[:, keep]

    # Gene Filtering
    gene_idx, selected_genes, scores = select_survival_genes_fast(
        expr_train,
        y_time_train,
        y_event_train,
        top_k=k
    )
    expr_train = expr_train.iloc[:, gene_idx]
    expr_test = expr_test.iloc[:, gene_idx]

    print("Top Genes:")
    print(selected_genes[:10])
    print("Final selected genes:", len(gene_idx))
    
    pre = SurvivalPreprocessor()
    pre.fit(Xc_train, expr_train)

    Xc_train, Xe_train = pre.transform(Xc_train, expr_train)
    Xc_test, Xe_test = pre.transform(Xc_test, expr_test)

    Xc_train = torch.tensor(Xc_train).float()
    Xe_train = torch.tensor(Xe_train).float()
    yt_train = torch.tensor(y_time_train).float()
    ye_train = torch.tensor(y_event_train).float()

    Xc_test = torch.tensor(Xc_test).float()
    Xe_test = torch.tensor(Xe_test).float()

    ae = train_survival_autoencoder(Xe_train, yt_train, ye_train, latent_dim=latent_dim_expr)

    final_model = train_dual_encoder_survival_net(
        Xc_train, Xe_train, yt_train, ye_train, ae,
        latent_dim_expr=latent_dim_expr,
        latent_dim_clin=latent_dim_clin
    )

    test_cindex = compute_cindex(final_model, y_time_test, y_event_test,
                                 Xc_test, Xe_test)

    print("\nCV mean:", np.mean(cv_scores))
    print("CV std:", np.std(cv_scores))
    print("TEST C-index:", test_cindex)

    return final_model, cv_scores, test_cindex

# %% [markdown]
# ### Load Data and Preprocessing

# %%
# Load clinical metadata
clinical = pd.read_csv(here.here("data", "processed", "clinical_data.csv"))
# Load expression data
expression_data = pd.read_csv(here.here("data", "processed", "expression_data.csv"))
# Mutation binary data
mutation_binary = pd.read_csv(here.here("data", "processed", "mutation_binary_data.csv"))
# Mutation classified data
mutation_classified = pd.read_csv(here.here("data", "processed", "mutation_classified_data.csv"))

pd.set_option('display.max_columns', None)

print("Data shapes:")
print(f"  Clinical: {clinical.shape}")
print(f"  Expression: {expression_data.shape}")
print(f"  Mutation Binary: {mutation_binary.shape}")
print(f"  Mutation Classified: {mutation_classified.shape}")
# Out:
# Data shapes:
#   Clinical: (1904, 31)
#   Expression: (1904, 489)
#   Mutation Binary: (1904, 173)
#   Mutation Classified: (1904, 173)

# %% [markdown]
# ## Preprocess Clinical Features

# %%
# Prepare clinical data
df = clinical.copy()
time_col = "overall_survival_months"
event_col = "death_from_cancer"

# Define outcome variables
df["event"] = (df[event_col] == "Died of Disease").astype(int)
df["time"] = df[time_col]

print(f"Event distribution:\n{df['event'].value_counts()}")

# Group rare cancer types into "Other" category
rare_threshold = 50

value_counts = df["cancer_type_detailed"].value_counts()
rare_classes = value_counts[value_counts < rare_threshold].index
df["cancer_type_detailed_clean"] = df["cancer_type_detailed"].replace(rare_classes, "Other")

# Do same for histologic subtype
value_counts = df["tumor_other_histologic_subtype"].value_counts()
rare_classes = value_counts[value_counts < rare_threshold].index
df["tumor_other_histologic_subtype_clean"] = df["tumor_other_histologic_subtype"].replace(rare_classes, "Other")

# Drop identifiers, outcome columns, and pre-modified columns
drop_cols = [
    "patient_id", "cancer_type", "cohort", "cancer_type_detailed",
    "er_status_measured_by_ihc", "her2_status_measured_by_snp6",
    "tumor_other_histologic_subtype", "integrative_cluster", "oncotree_code",
    "radio_therapy", "chemotherapy", "type_of_breast_surgery", "hormone_therapy",
    "overall_survival", "nottingham_prognostic_index", "3-gene_classifier_subtype",
    "tumor_other_histologic_subtype_clean", time_col, event_col
]

X_clinical = df.drop(columns=drop_cols + ["event", "time"])
y_time = df["time"].values
y_event = df["event"].values

# Identify feature types
numeric_cols = X_clinical.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_cols = X_clinical.select_dtypes(include=["object", "category"]).columns.tolist()

# Fill missing categorical data
X_clinical[categorical_cols] = X_clinical[categorical_cols].fillna("Unknown")

print(f"\nClinical features:")
print(f"  Numeric: {len(numeric_cols)}")
print(f"  Categorical: {len(categorical_cols)}")
# Out:
# Event distribution:
# event
# 0    1282
# 1     622
# Name: count, dtype: int64
#
# Clinical features:
#   Numeric: 5
#   Categorical: 9

# %% [markdown]
# ## Preprocess Mutation Features

# %%
# Option A: TMB only (1 feature) — simplest possible mutation signal
tmb_only = mutation_binary.sum(axis=1).values.astype(np.float32).reshape(-1, 1)

# Option B: Top mutated genes only — keep genes mutated in >5% of patients
mutation_freq = mutation_binary.mean(axis=0)
frequent_genes = mutation_freq[mutation_freq > 0.05].index
print(f"Genes mutated in >5% of patients: {len(frequent_genes)}")
print(frequent_genes.tolist())

# mut_frequent = mutation_binary[frequent_genes].values.astype(np.float32)
mut_frequent = mutation_binary[frequent_genes].astype(np.float32)

mut_frequent["TMB"] = tmb_only

print(f"Frequent mutation + TMB matrix shape: {mut_frequent.shape}")
# Out:
# Genes mutated in >5% of patients: 25
# ['pik3ca_mut', 'tp53_mut', 'muc16_mut', 'ahnak2_mut', 'kmt2c_mut', 'syne1_mut', 'gata3_mut', 'map3k1_mut', 'ahnak_mut', 'dnah11_mut', 'cdh1_mut', 'dnah2_mut', 'kmt2d_mut', 'ush2a_mut', 'ryr2_mut', 'dnah5_mut', 'herc2_mut', 'pde4dip_mut', 'akap9_mut', 'tg_mut', 'birc6_mut', 'utrn_mut', 'tbx3_mut', 'col6a3_mut', 'arid1a_mut']
# Frequent mutation + TMB matrix shape: (1904, 26)

# %%
# Final check of shapes of input data
print(X_clinical.shape)
print(mutation_binary.shape)
print(mut_frequent.shape)
print(expression_data.shape)
print(X_clinical.shape)
print(y_time.shape)
print(y_event.shape)
# Out:
# (1904, 14)
# (1904, 173)
# (1904, 26)
# (1904, 489)
# (1904, 14)
# (1904,)
# (1904,)

# %% [markdown]
# # Run with full mutation dataset, and top genes = 100

# %%
final_model, cv_scores, test_cindex = run_pipeline(X_clinical,mutation_binary,expression_data,y_time,y_event)
# Out:
# ================ FOLD 1 ================
# Selected 100 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'bcl2' 'fancd2' 'e2f7' 'stat5b' 'cdc25a' 'chek1'
#  'mapt']
# [Feature Filter]
# Original: 211 features
# Kept: 209 features
# Dropped: 2 constant features
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 final_model, cv_scores, test_cindex = run_pipeline(X_clinical,mutation_binary,expression_data,y_time,y_event)
#
# Cell In[15], line 109, in run_pipeline(clinical_df, mutation_df, X_expr, y_time, y_event, k, latent_dim_clin, latent_dim_expr)
#     104 Xe_va = torch.tensor(Xe_va).float()
#     106 # ============================================================
#     107 # 7. AUTOENCODER (PER FOLD)
#     108 # ============================================================
# --> 109 ae = train_survival_autoencoder(Xe_tr, yt_tr, ye_tr, latent_dim=latent_dim_expr)
#     111 # ============================================================
#     112 # 8. DUAL ENCODER MODEL
#     113 # ============================================================
#     114 model = train_dual_encoder_survival_net(
#     115     Xc_tr, Xe_tr, yt_tr, ye_tr, ae,
#     116     latent_dim_clin=latent_dim_clin,
#     117     latent_dim_expr=latent_dim_expr
#     118 )
#
# Cell In[12], line 31, in train_survival_autoencoder(X_expr, y_time, y_event, latent_dim, epochs)
#      27 surv_loss = cox_loss(risk, y_time, y_event)
#      29 loss = recon_loss + 0.05 * surv_loss
# ---> 31 loss.backward()
#      32 optimizer.step()
#      34 if loss.item() < best_loss:
#
# File ~/miniforge3/envs/bc_survival/lib/python3.11/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)    579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/miniforge3/envs/bc_survival/lib/python3.11/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniforge3/envs/bc_survival/lib/python3.11/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Run with only top mutations, with TMB added, and top genes = 100

# %%
final_model, cv_scores, test_cindex = run_pipeline(X_clinical,mut_frequent,expression_data,y_time,y_event)
# Out:
# ================ FOLD 1 ================
# Selected 100 genes
# Top genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'e2f7' 'fancd2' 'eif4ebp1' 'stat5b' 'mapt'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6687116564417178
#
# ================ FOLD 2 ================
# Selected 100 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'fancd2' 'ccne1' 'chek1' 'cdc25a' 'slc19a1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6013602871717363
#
# ================ FOLD 3 ================
# Selected 100 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'mapt' 'gsk3b' 'e2f2' 'chek1' 'ccne1' 'cdk1'
#  'e2f8']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6034389584868582
#
# ================ FOLD 4 ================
# Selected 100 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'rps6kb2' 'bcl2' 'stat5a'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6359751175269481
#
# ================ FOLD 5 ================
# Selected 100 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'gsk3b' 'e2f2' 'mapt' 'e2f7' 'slc19a1' 'fancd2'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6031157618131482
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'mapt' 'chek1'
#  'cdc25a']
# Final selected genes: 100
#
# CV mean: 0.6225203562880818
# CV std: 0.026469051224673232
# TEST C-index: 0.6572216265890641

# %% [markdown]
# ## Run with different values for K

# %%
for k in [25, 50, 200]:
    print(f"\n\nTOP {k} GENES USED:\n")
    final_model, cv_scores, test_cindex = run_pipeline(X_clinical,mut_frequent,expression_data,y_time,y_event, k=k)
# Out:
# TOP 25 GENES USED:
#
#
# ================ FOLD 1 ================
# Selected 25 genes
# Top genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'e2f7' 'fancd2' 'eif4ebp1' 'stat5b' 'mapt'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6836319018404908
#
# ================ FOLD 2 ================
# Selected 25 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'fancd2' 'ccne1' 'chek1' 'cdc25a' 'slc19a1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6552994521065558
#
# ================ FOLD 3 ================
# Selected 25 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'mapt' 'gsk3b' 'e2f2' 'chek1' 'ccne1' 'cdk1'
#  'e2f8']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6348808646524196
#
# ================ FOLD 4 ================
# Selected 25 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'rps6kb2' 'bcl2' 'stat5a'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6715893442233725
#
# ================ FOLD 5 ================
# Selected 25 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'gsk3b' 'e2f2' 'mapt' 'e2f7' 'slc19a1' 'fancd2'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.660363192717376
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'mapt' 'chek1'
#  'cdc25a']
# Final selected genes: 25
#
# CV mean: 0.661152951108043
# CV std: 0.016366619827547203
# TEST C-index: 0.6534231888497473
#
#
# TOP 50 GENES USED:
#
#
# ================ FOLD 1 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'e2f7' 'fancd2' 'eif4ebp1' 'stat5b' 'mapt'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6777914110429448
#
# ================ FOLD 2 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'fancd2' 'ccne1' 'chek1' 'cdc25a' 'slc19a1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6126960136028717
#
# ================ FOLD 3 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'mapt' 'gsk3b' 'e2f2' 'chek1' 'ccne1' 'cdk1'
#  'e2f8']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6035863424220094
#
# ================ FOLD 4 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'rps6kb2' 'bcl2' 'stat5a'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.616126121848141
#
# ================ FOLD 5 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'gsk3b' 'e2f2' 'mapt' 'e2f7' 'slc19a1' 'fancd2'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6640232743653512
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'mapt' 'chek1'
#  'cdc25a']
# Final selected genes: 50
#
# CV mean: 0.6348446326562636
# CV std: 0.030046109854678253
# TEST C-index: 0.6297442181038444
#
#
# TOP 200 GENES USED:
#
#
# ================ FOLD 1 ================
# Selected 200 genes
# Top genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'e2f7' 'fancd2' 'eif4ebp1' 'stat5b' 'mapt'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6397055214723927
#
# ================ FOLD 2 ================
# Selected 200 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'fancd2' 'ccne1' 'chek1' 'cdc25a' 'slc19a1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5738711505762327
#
# ================ FOLD 3 ================
# Selected 200 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'mapt' 'gsk3b' 'e2f2' 'chek1' 'ccne1' 'cdk1'
#  'e2f8']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6122328666175387
#
# ================ FOLD 4 ================
# Selected 200 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'rps6kb2' 'bcl2' 'stat5a'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6058692245595707
#
# ================ FOLD 5 ================
# Selected 200 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'gsk3b' 'e2f2' 'mapt' 'e2f7' 'slc19a1' 'fancd2'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5744451222373422
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'mapt' 'chek1'
#  'cdc25a']
# Final selected genes: 200
#
# CV mean: 0.6012247770926155
# CV std: 0.024855129905309706
# TEST C-index: 0.6739776382294379

# %%
final_model, cv_scores, test_cindex = run_pipeline(X_clinical,mut_frequent,expression_data,y_time,y_event, k=10)
# Out:
# ================ FOLD 1 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'e2f7' 'fancd2' 'eif4ebp1' 'stat5b' 'mapt'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.7059141104294478
#
# ================ FOLD 2 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'fancd2' 'ccne1' 'chek1' 'cdc25a' 'slc19a1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6339977328547137
#
# ================ FOLD 3 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'mapt' 'gsk3b' 'e2f2' 'chek1' 'ccne1' 'cdk1'
#  'e2f8']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6185703758290346
#
# ================ FOLD 4 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'rps6kb2' 'bcl2' 'stat5a'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.669262548079206
#
# ================ FOLD 5 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'gsk3b' 'e2f2' 'mapt' 'e2f7' 'slc19a1' 'fancd2'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6583923795223124
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'stat5b' 'fancd2' 'e2f7' 'mapt' 'chek1'
#  'cdc25a']
# Final selected genes: 10
#
# CV mean: 0.6572274293429429
# CV std: 0.03016813117330213
# TEST C-index: 0.641139531321795

# %%
for k in [10, 15, 25, 100,150, 200]:
    for l in [8,16,32,64]:
        print(f"\n\nSELECTED GENES: {k}\nAE LAT DIMS: {l}\n")
        final_model, cv_scores, test_cindex = run_pipeline(X_clinical,mut_frequent,expression_data,y_time,y_event, k=k, latent_dim_expr=l)
# Out:
# SELECTED GENES: 10
# AE LAT DIMS: 8
#
#
# ================ FOLD 1 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'bcl2' 'fancd2' 'e2f7' 'stat5b' 'cdc25a' 'chek1'
#  'mapt']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6885889570552147
#
# ================ FOLD 2 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'fancd2' 'bcl2' 'cdc25a' 'slc19a1' 'e2f7' 'ccnb1'
#  'ccne1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6294634422822596
#
# ================ FOLD 3 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'gsk3b' 'mapt' 'e2f2' 'chek1' 'cdk1' 'stat5a'
#  'fancd2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.609334315892901
#
# ================ FOLD 4 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'stat5b' 'e2f2' 'rps6kb2' 'stat5a' 'fancd2' 'e2f7' 'bcl2'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6381119711287335
#
# ================ FOLD 5 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'stat5b' 'gsk3b' 'bcl2' 'e2f2' 'mapt' 'slc19a1' 'fancd2' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6617709164281357
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'stat5b' 'fancd2' 'mapt' 'e2f7' 'stat5a'
#  'cdc25a']
# Final selected genes: 10
#
# CV mean: 0.645453920557449
# CV std: 0.027353614700488655
# TEST C-index: 0.6600091897687241
#
#
# SELECTED GENES: 10
# AE LAT DIMS: 16
#
#
# ================ FOLD 1 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'bcl2' 'fancd2' 'e2f7' 'stat5b' 'cdc25a' 'chek1'
#  'mapt']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6997791411042945
#
# ================ FOLD 2 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'fancd2' 'bcl2' 'cdc25a' 'slc19a1' 'e2f7' 'ccnb1'
#  'ccne1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6174664651426413
#
# ================ FOLD 3 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'gsk3b' 'mapt' 'e2f2' 'chek1' 'cdk1' 'stat5a'
#  'fancd2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.638761974944731
#
# ================ FOLD 4 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'stat5b' 'e2f2' 'rps6kb2' 'stat5a' 'fancd2' 'e2f7' 'bcl2'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6395840258321858
#
# ================ FOLD 5 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'stat5b' 'gsk3b' 'bcl2' 'e2f2' 'mapt' 'slc19a1' 'fancd2' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6466144244756229
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'stat5b' 'fancd2' 'mapt' 'e2f7' 'stat5a'
#  'cdc25a']
# Final selected genes: 10
#
# CV mean: 0.6484412062998951
# CV std: 0.027460853726850865
# TEST C-index: 0.6239240312452137
#
#
# SELECTED GENES: 10
# AE LAT DIMS: 32
#
#
# ================ FOLD 1 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'bcl2' 'fancd2' 'e2f7' 'stat5b' 'cdc25a' 'chek1'
#  'mapt']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6727361963190184
#
# ================ FOLD 2 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'fancd2' 'bcl2' 'cdc25a' 'slc19a1' 'e2f7' 'ccnb1'
#  'ccne1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6337143396939354
#
# ================ FOLD 3 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'gsk3b' 'mapt' 'e2f2' 'chek1' 'cdk1' 'stat5a'
#  'fancd2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5951363301400148
#
# ================ FOLD 4 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'gsk3b' 'stat5b' 'e2f2' 'rps6kb2' 'stat5a' 'fancd2' 'e2f7' 'bcl2'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6504107507478988
#
# ================ FOLD 5 ================
# Selected 10 genes
# Top genes:
# ['aurka' 'stat5b' 'gsk3b' 'bcl2' 'e2f2' 'mapt' 'slc19a1' 'fancd2' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.645816714372859
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'stat5b' 'fancd2' 'mapt' 'e2f7' 'stat5a'
#  'cdc25a']
# Final selected genes: 10
#
# CV mean: 0.
 'cdk1' 'stat5a'
#  'fancd2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5910587079341685
#
# ================ FOLD 4 ================
# Selected 200 genes
# Top genes:
# ['aurka' 'gsk3b' 'stat5b' 'e2f2' 'rps6kb2' 'stat5a' 'fancd2' 'e2f7' 'bcl2'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5877297117621919
#
# ================ FOLD 5 ================
# Selected 200 genes
# Top genes:
# ['aurka' 'stat5b' 'gsk3b' 'bcl2' 'e2f2' 'mapt' 'slc19a1' 'fancd2' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5688142273943034
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'stat5b' 'fancd2' 'mapt' 'e2f7' 'stat5a'
#  'cdc25a']
# Final selected genes: 200
#
# CV mean: 0.5981022455172983
# CV std: 0.021616693707281497
# TEST C-index: 0.6556287333435442

# %% [markdown]
# ### Model training with selected hyperparameters:
# - Top genes: 150
# - AE latent dimension: 32
# - Clinical latent dimension: 32
#
# As this provided the best balance of Cross validation C-index and Test set C-index
#
# ## Now, run across many different random seeds:

# %%
import pandas as pd
import numpy as np

seeds = [
    1, 2, 3, 4, 5,
    10, 20, 30, 40, 50,
    100, 200, 300, 400, 500
]

results = []

for seed in seeds:

    print("\n" + "="*80)
    print(f"SEED {seed}")
    print("="*80)

    final_model, cv_scores, test_cindex = run_pipeline(
        X_clinical,
        mut_frequent,
        expression_data,
        y_time,
        y_event,
        k=150,
        latent_dim_expr=32,
        latent_dim_clin=64,
        random_state=seed
    )

    results.append({
        "seed": seed,
        "cv_mean": np.mean(cv_scores),
        "cv_std": np.std(cv_scores),
        "test_cindex": test_cindex
    })

results_df = pd.DataFrame(results)

print(results_df)
# Out:
# ================================================================================
# SEED 1
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5a' 'fancd2' 'e2f2' 'bcl2' 'gsk3b' 'mapt' 'stat5b' 'tubb4b'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6158260626137265
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'e2f2' 'mapt' 'gsk3b' 'cir1' 'aph1b' 'rps6kb2'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5672118265311134
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'e2f2' 'gsk3b' 'diras3' 'fancd2' 'chek1' 'stat5b' 'mmp15'
#  'bcl2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6080501484658528
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'cdk1' 'mapt' 'e2f2' 'bcl2' 'chek1' 'gsk3b' 'ccnb1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.630742808072134
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'e2f2' 'fancd2' 'mapt' 'stat5a' 'gsk3b' 'cdk1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6267649451969559
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'mapt' 'bcl2' 'gsk3b' 'cdk1' 'chek1' 'stat5a'
#  'stat5b']
# Final selected genes: 150
#
# CV mean: 0.6097191581759566
# CV std: 0.022713457812105476
# TEST C-index: 0.651043952598909
#
# ================================================================================
# SEED 2
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'chek1' 'cdk1' 'bcl2' 'cdk2' 'ccne1' 'mapt' 'aph1b'
#  'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6339340910171668
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'e2f7' 'gsk3b' 'e2f2' 'chek1' 'diras3' 'bcl2' 'ccne1'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.615028103737304
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'chek1' 'fancd2' 'bcl2' 'cdk1' 'stat5b' 'e2f7' 'ccne1' 'aph1b'
#  'cdk2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6042323492882392
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'ccnb1' 'e2f2' 'diras3' 'chek1' 'slc19a1'
#  'gsk3b']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6766924338252518
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'e2f7' 'fancd2' 'bcl2' 'cdk1' 'diras3' 'chek1' 'stat5a' 'stat5b'
#  'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6597642860496784
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'bcl2' 'chek1' 'cdk1' 'e2f7' 'e2f2' 'ccne1' 'cdk2'
#  'stat5b']
# Final selected genes: 150
#
# CV mean: 0.637930252783528
# CV std: 0.02703796637158541
# TEST C-index: 0.6152323498916015
#
# ================================================================================
# SEED 3
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'bcl2' 'gata3' 'fancd2' 'gsk3b' 'e2f7' 'igf1r' 'e2f2'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6141739748755629
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'mapt' 'cdc25a' 'fancd2' 'e2f7' 'chek1' 'stat5a'
#  'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6244014556598353
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'fancd2' 'mapt' 'cdk1' 'e2f2' 'cdc25a' 'stat5b' 'ccnb1'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6215517669864308
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'mapt' 'fancd2' 'e2f2' 'gsk3b' 'stat5b' 'chek1' 'ccnb1'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6004232397075798
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'fancd2' 'mapt' 'gsk3b' 'aph1b' 'chek1' 'cdk1' 'cdc25a'
#  'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6022578839335697
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'mapt' 'fancd2' 'gsk3b' 'e2f2' 'cdk1' 'chek1' 'cdc25a'
#  'stat5b']
# Final selected genes: 150
#
# CV mean: 0.6125616642325957
# CV std: 0.009768432756328698
# TEST C-index: 0.6146487942296381
#
# ================================================================================
# SEED 4
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'bcl2' 'e2f2' 'stat5b' 'ccne1' 'gsk3b' 'cdc25a' 'gata3'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.597129840546697
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'mapt' 'gsk3b' 'fancd2' 'cdc25a' 'ccne1' 'cdk1'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5524787637375822
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'gsk3b' 'mapt' 'e2f2' 'aph1b' 'stat5b' 'cdk1' 'stat5a'
#  'fancd2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6238072519083969
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'ccne1' 'mapt' 'gsk3b' 'stat5b' 'cdc25a' 'e2f2' 'bcl2' 'fancd2'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6254443759776271
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'mapt' 'stat5b' 'e2f2' 'cdk1' 'bcl2' 'ccnb1' 'slc19a1'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.566923304708321
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'mapt' 'bcl2' 'stat5b' 'gsk3b' 'e2f2' 'fancd2' 'cdk1' 'ccne1'
#  'cdc25a']
# Final selected genes: 150
#
# CV mean: 0.5931567073757249
# CV std: 0.029463949922669645
# TEST C-index: 0.6491952125464301
#
# ================================================================================
# SEED 5
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'gsk3b' 'bcl2' 'fancd2' 'cdc25a' 'igf1r' 'notch3' 'stat5b'
#  'stat5a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.645745518551114
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f7' 'cdc25a' 'stat5a' 'diras3' 'mapt' 'fancd2' 'bcl2'
#  'cir1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6427400084336785
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'mapt' 'chek1' 'stat5b' 'cdk1' 'igf1r' 'aph1b' 'eif4ebp1'
#  'bcl2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6519224056250935
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'gsk3b' 'bcl2' 'stat5a' 'igf1r' 'ccne1' 'eif4ebp1' 'e2f2'
#  'mmp15']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.654842912986825
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5a' 'mapt' 'bcl2' 'igf1r' 'fancd2' 'stat5b' 'chek1' 'cdk1'
#  'gsk3b']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6668918918918919
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'gsk3b' 'mapt' 'stat5a' 'bcl2' 'igf1r' 'fancd2' 'cdc25a' 'stat5b'
#  'chek1']
# Final selected genes: 150
#
# CV mean: 0.6524285474977206
# CV std: 0.008411947889416137
# TEST C-index: 0.6387633842916383
#
# ================================================================================
# SEED 10
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'mapt' 'ccnb1' 'aph1b' 'e2f2' 'gsk3b' 'igf1r' 'e2f7'
#  'ncoa3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.636487310597176
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'gsk3b' 'e2f2' 'mapt' 'igf1r' 'rps6kb2' 'stat5b' 'aph1b'
#  'fancd2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6190257352941176
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'mapt' 'gsk3b' 'fancd2' 'stat5a' 'aph1b' 'e2f2' 'diras3'
#  'ncoa3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5725330334551588
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'e2f2' 'bcl2' 'e2f7' 'map2k4' 'aph1b' 'mapt' 'fancd2'
#  'igf1r']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6472945891783567
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'mapt' 'fancd2' 'stat5b' 'aph1b' 'ccnb1'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6358183800931893
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'gsk3b' 'mapt' 'e2f2' 'aph1b' 'fancd2' 'igf1r' 'stat5b'
#  'ccnb1']
# Final selected genes: 150
#
# CV mean: 0.6222318097235997
# CV std: 0.026443163159463556
# TEST C-index: 0.6234191016136066
#
# ================================================================================
# SEED 20
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'stat5b' 'igf1r' 'bcl2' 'mapt' 'vegfa' 'fancd2' 'map2k4'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5809122807017544
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'stat5b' 'stat5a' 'e2f2' 'mapt' 'fancd2' 'e2f7'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6048248953178531
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'fancd2' 'stat5a' 'igf1r'
#  'eif4ebp1' 'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6261538461538462
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5b' 'bcl2' 'mapt' 'gsk3b' 'igf1r' 'stat5a' 'fancd2'
#  'eif4ebp1' 'map2k4']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6437303696545059
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'igf1r' 'bcl2' 'mapt' 'e2f2' 'fancd2' 'e2f7' 'stat5b'
#  'rps6kb2']
# [Feature Filter]
# Original: 63 features
# Kept: 63 features
# Dropped: 0 constant features
# C-index: 0.62616290108221
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'igf1r' 'fancd2' 'e2f2' 'stat5a'
#  'map2k4']
# Final selected genes: 150
#
# CV mean: 0.6163568585820338
# CV std: 0.02159052024046603
# TEST C-index: 0.6398456615847921
#
# ================================================================================
# SEED 30
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'gsk3b' 'ccne1' 'mapt' 'ccnb1' 'stat5b' 'fancd2' 'mmp15'
#  'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5943553619427194
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'cdk1' 'mapt' 'fancd2' 'gsk3b' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.586358122608939
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'ccnb1' 'cdc25a' 'ccne1' 'bcl2' 'mapt'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6204489035995036
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'ccne1' 'ccnb1' 'stat5b' 'bcl2' 'stat5a' 'e2f2' 'fancd2'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6223570683606713
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'fancd2' 'ccne1' 'gsk3b' 'bcl2' 'ccnb1' 'e2f2' 'gata3'
#  'cdc25a']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6613589160320443
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'gsk3b' 'bcl2' 'fancd2' 'ccne1' 'mapt' 'ccnb1' 'stat5b' 'e2f2'
#  'cdk1']
# Final selected genes: 150
#
# CV mean: 0.6169756745087756
# CV std: 0.026305922805117364
# TEST C-index: 0.6845758047146105
#
# ================================================================================
# SEED 40
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'stat5b' 'fancd2' 'ccnb1' 'ccne1' 'stat5a' 'e2f2' 'cdk1'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.631073610707012
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'mapt' 'igf1r' 'ccne1' 'fancd2' 'cdk1' 'gsk3b' 'e2f7'
#  'stat5b']
# [Feature Filter]
# Original: 63 features
# Kept: 63 features
# Dropped: 0 constant features
# C-index: 0.6372976043935233
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'eif4ebp1' 'e2f2' 'igf1r'
#  'aph1b']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6199298453633714
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['gsk3b' 'aurka' 'stat5b' 'bcl2' 'mapt' 'e2f2' 'stat5a' 'ccnb1' 'fancd2'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6306053811659192
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5b' 'bcl2' 'mapt' 'gsk3b' 'stat5a' 'e2f2' 'eif4ebp1' 'ccnb1'
#  'ccne1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5857404537128365
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'mapt' 'gsk3b' 'bcl2' 'stat5b' 'ccne1' 'e2f2' 'fancd2' 'ccnb1'
#  'stat5a']
# Final selected genes: 150
#
# CV mean: 0.6209293790685325
# CV std: 0.018459191681814962
# TEST C-index: 0.6273490976975731
#
# ================================================================================
# SEED 50
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'mapt' 'map2k4' 'stat5b' 'igf1r' 'ccne1' 'e2f2'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5854837913850102
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'e2f2' 'bcl2' 'cdk1' 'stat5b' 'fancd2' 'chek1' 'gsk3b'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6443104747550866
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'bcl2' 'e2f2' 'mapt' 'fancd2' 'e2f7' 'cdc25a' 'stat5a'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6183609366076528
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'e2f7' 'slc19a1' 'fancd2' 'gsk3b' 'bcl2' 'stat5a' 'stat5b' 'e2f2'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6274567465568789
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'gsk3b' 'mapt' 'e2f8' 'stat5b' 'cdk1' 'e2f7'
#  'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5407443924081834
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'gsk3b' 'mapt' 'e2f2' 'fancd2' 'stat5b' 'e2f7' 'cdk1'
#  'ccne1']
# Final selected genes: 150
#
# CV mean: 0.6032712683425624
# CV std: 0.0366683963609103
# TEST C-index: 0.6606926688121881
#
# ================================================================================
# SEED 100
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'stat5b' 'stat5a' 'mapt' 'fancd2' 'e2f2' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6736127154276209
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'mapt' 'bcl2' 'fancd2' 'e2f2' 'e2f7' 'igf1r' 'stat5b'
#  'ccne1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.612536472482141
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'mapt' 'ccnb1' 'stat5b' 'bcl2' 'igf1r' 'stat5a' 'chek1'
#  'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6336509412038113
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5a' 'stat5b' 'fancd2' 'gsk3b' 'ccnb1' 'e2f7' 'bcl2' 'mapt'
#  'e2f2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6177606177606177
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5a' 'gsk3b' 'e2f7' 'stat5b' 'ccnb1' 'mapt' 'e2f8' 'fancd2'
#  'tubb4b']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5773969965344629
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'gsk3b' 'stat5a' 'stat5b' 'mapt' 'fancd2' 'bcl2' 'e2f7' 'ccnb1'
#  'e2f2']
# Final selected genes: 150
#
# CV mean: 0.6229915486817308
# CV std: 0.03127829795179276
# TEST C-index: 0.6051939924906132
#
# ================================================================================
# SEED 200
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5899695180034292
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6251528640610478
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5969392681278363
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6073743338614431
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6256591359876155
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 150
#
# CV mean: 0.6090190240082743
# CV std: 0.014482425959570307
# TEST C-index: 0.657878861003861
#
# ================================================================================
# SEED 300
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'fancd2' 'chek1' 'e2f2' 'e2f7' 'mapt' 'stat5a' 'gsk3b'
#  'eif4ebp1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6255375293197811
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'stat5b' 'mapt' 'igf1r' 'cdk1' 'gsk3b' 'fancd2' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.629665117616059
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5b' 'e2f2' 'gsk3b' 'bcl2' 'stat5a' 'cdc25a' 'e2f7' 'fancd2'
#  'mapt']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6367997673967823
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'e2f2' 'mapt' 'bcl2' 'stat5b' 'gsk3b' 'e2f7' 'ccne1' 'diras3'
#  'aph1b']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6506952182549295
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5a' 'fancd2' 'mapt' 'e2f7' 'cdk1' 'stat5b' 'bcl2' 'e2f2'
#  'e2f8']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6148114811481148
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'bcl2' 'stat5b' 'mapt' 'e2f2' 'gsk3b' 'fancd2' 'e2f7' 'stat5a'
#  'cdk1']
# Final selected genes: 150
#
# CV mean: 0.6315018227471334
# CV std: 0.011949631234037595
# TEST C-index: 0.6375805938647469
#
# ================================================================================
# SEED 400
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5b' 'gsk3b' 'stat5a' 'fancd2' 'e2f7' 'bcl2' 'ccnb1' 'cdk1'
#  'mapt']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6472408703518545
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'cdk1' 'ccnb1' 'fancd2' 'mapt' 'stat5b' 'chek1' 'igf1r' 'bcl2'
#  'gsk3b']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6367843253089155
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'stat5b' 'chek1' 'gsk3b' 'e2f2' 'mapt' 'bcl2' 'ccnb1' 'fancd2'
#  'cdk1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6512580190181537
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'fancd2' 'ccnb1' 'bcl2' 'igf1r' 'gsk3b' 'mapt' 'cdk1' 'ccne1'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.612007380422955
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'e2f7' 'gsk3b' 'ccnb1' 'stat5a' 'fancd2' 'stat5b' 'chek1' 'e2f2'
#  'bcl2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6247906197654941
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'ccnb1' 'gsk3b' 'stat5b' 'bcl2' 'cdk1' 'mapt' 'chek1'
#  'e2f7']
# Final selected genes: 150
#
# CV mean: 0.6344162429734745
# CV std: 0.014481257159728497
# TEST C-index: 0.5975171206104005
#
# ================================================================================
# SEED 500
# ================================================================================
#
# ================ FOLD 1 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'e2f2' 'cdk1' 'fancd2' 'e2f7' 'cdk2' 'bcl2' 'gsk3b'
#  'stat5b']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.628363601787582
#
# ================ FOLD 2 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'bcl2' 'mapt' 'gsk3b' 'stat5b' 'e2f2' 'ccnb1' 'diras3' 'cdk1'
#  'aph1b']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6907472969093866
#
# ================ FOLD 3 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'mapt' 'ccnb1' 'stat5b' 'bcl2' 'stat5a' 'gsk3b' 'aph1b' 'fancd2'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6179872758820127
#
# ================ FOLD 4 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'e2f2' 'fancd2' 'e2f7' 'bcl2' 'ccnb1' 'mapt' 'gsk3b' 'stat5b'
#  'chek1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6267538417485922
#
# ================ FOLD 5 ================
# Selected 150 genes
# Top genes:
# ['aurka' 'gsk3b' 'ccnb1' 'mapt' 'fancd2' 'e2f7' 'e2f2' 'bcl2' 'stat5b'
#  'ccne1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6667153071647454
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'mapt' 'bcl2' 'ccnb1' 'e2f2' 'gsk3b' 'stat5b' 'fancd2' 'e2f7'
#  'aph1b']
# Final selected genes: 150
#
# CV mean: 0.6461134646984638
# CV std: 0.02791970638202789
# TEST C-index: 0.6449415446929946
#     seed   cv_mean    cv_std  test_cindex
# 0      1  0.609719  0.022713     0.651044
# 1      2  0.637930  0.027038     0.615232
# 2      3  0.612562  0.009768     0.614649
# 3      4  0.593157  0.029464     0.649195
# 4      5  0.652429  0.008412     0.638763
# 5     10  0.622232  0.026443     0.623419
# 6     20  0.616357  0.021591     0.639846
# 7     30  0.616976  0.026306     0.684576
# 8     40  0.620929  0.018459     0.627349
# 9     50  0.603271  0.036668     0.660693
# 10   100  0.622992  0.031278     0.605194
# 11   200  0.609019  0.014482     0.657879
# 12   300  0.631502  0.011950     0.637581
# 13   400  0.634416  0.014481     0.597517
# 14   500  0.646113  0.027920     0.644942

# %%
print("\nSUMMARY")
print("="*50)

print(
    f"CV Mean: "
    f"{results_df.cv_mean.mean():.3f} ± "
    f"{results_df.cv_mean.std():.3f}"
)

print(
    f"Test Mean: "
    f"{results_df.test_cindex.mean():.3f} ± "
    f"{results_df.test_cindex.std():.3f}"
)
# Out:
# SUMMARY
# ==================================================
# CV Mean: 0.622 ± 0.016
# Test Mean: 0.637 ± 0.023

# %% [markdown]
# ## Hyperparameter + Seed Search

# %%
import pandas as pd
import numpy as np

def run_hyperparameter_search(
    X_clinical,
    mutation_binary,
    expression_data,
    y_time,
    y_event,
    gene_grid=[10,100,200],
    ae_grid=[8,16,32,64],
    clin_grid=[32,64],
    seeds=[1,10,20,50,100]
):

    results = []

    total_runs = (
        len(gene_grid)
        * len(ae_grid)
        * len(clin_grid)
        * len(seeds)
    )

    run_num = 0

    for seed in seeds:

        print("\n")
        print("="*80)
        print(f"SEED {seed}")
        print("="*80)

        for k in gene_grid:

            for ae_dim in ae_grid:

                for clin_dim in clin_grid:

                    run_num += 1

                    print(
                        f"\n[{run_num}/{total_runs}] "
                        f"k={k} "
                        f"AE={ae_dim} "
                        f"CLIN={clin_dim}"
                    )

                    final_model, cv_scores, test_cindex = run_pipeline(
                        X_clinical,
                        mutation_binary,
                        expression_data,
                        y_time,
                        y_event,
                        k=k,
                        latent_dim_expr=ae_dim,
                        latent_dim_clin=clin_dim,
                        random_state=seed
                    )

                    results.append({
                        "seed": seed,
                        "top_genes": k,
                        "ae_latent": ae_dim,
                        "clin_latent": clin_dim,
                        "cv_mean": np.mean(cv_scores),
                        "cv_std": np.std(cv_scores),
                        "test_cindex": test_cindex
                    })

    return pd.DataFrame(results)

# %%
results_df = run_hyperparameter_search(
    X_clinical,
    mut_frequent,
    expression_data,
    y_time,
    y_event,
    gene_grid=[15,50,100,250],
    ae_grid=[8,16,32,64],
    clin_grid=[16,32,64],
    seeds=[1,10,20,50,100,200]
)
# Out:
# ================================================================================
# SEED 1
# ================================================================================
#
# [1/288] k=15 AE=8 CLIN=16
#
# ================ FOLD 1 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'stat5a' 'fancd2' 'e2f2' 'bcl2' 'gsk3b' 'mapt' 'stat5b' 'tubb4b'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6642560537488919
#
# ================ FOLD 2 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'e2f2' 'mapt' 'gsk3b' 'cir1' 'aph1b' 'rps6kb2'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6309611512204705
#
# ================ FOLD 3 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'mapt' 'e2f2' 'gsk3b' 'diras3' 'fancd2' 'chek1' 'stat5b' 'mmp15'
#  'bcl2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6378847150869585
#
# ================ FOLD 4 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'fancd2' 'cdk1' 'mapt' 'e2f2' 'bcl2' 'chek1' 'gsk3b' 'ccnb1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.644578025857545
#
# ================ FOLD 5 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'bcl2' 'e2f2' 'fancd2' 'mapt' 'stat5a' 'gsk3b' 'cdk1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6648159670703107
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'mapt' 'bcl2' 'gsk3b' 'cdk1' 'chek1' 'stat5a'
#  'stat5b']
# Final selected genes: 15
#
# CV mean: 0.6484991825968354
# CV std: 0.013785074387227852
# TEST C-index: 0.6465922628377955
#
# [2/288] k=15 AE=8 CLIN=32
#
# ================ FOLD 1 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'stat5a' 'fancd2' 'e2f2' 'bcl2' 'gsk3b' 'mapt' 'stat5b' 'tubb4b'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6708346941632063
#
# ================ FOLD 2 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'e2f2' 'mapt' 'gsk3b' 'cir1' 'aph1b' 'rps6kb2'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6121997937232946
#
# ================ FOLD 3 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'mapt' 'e2f2' 'gsk3b' 'diras3' 'fancd2' 'chek1' 'stat5b' 'mmp15'
#  'bcl2']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6588584625536127
#
# ================ FOLD 4 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'fancd2' 'cdk1' 'mapt' 'e2f2' 'bcl2' 'chek1' 'gsk3b' 'ccnb1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6456275941033348
#
# ================ FOLD 5 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'bcl2' 'e2f2' 'fancd2' 'mapt' 'stat5a' 'gsk3b' 'cdk1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6796056095342938
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'mapt' 'bcl2' 'gsk3b' 'cdk1' 'chek1' 'stat5a'
#  'stat5b']
# Final selected genes: 15
#
# CV mean: 0.6534252308155484
# CV std: 0.023572702232764618
# TEST C-index: 0.6533324973352561
#
# [3/288] k=15 AE=8 CLIN=64
#
# ================ FOLD 1 ================
# Selected 15 genes
# Top genes:
# ['aurka' 'stat5a' 'fancd2' 'e2f2' 'bcl2' 'gsk3b' 'mapt' 'stat5b' 'tubb4b'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.
#
# ================ FOLD 1 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6041626976566965
#
# ================ FOLD 2 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6269627745438536
#
# ================ FOLD 3 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6338225354832481
#
# ================ FOLD 4 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6141917518843919
#
# ================ FOLD 5 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6089207101736732
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 250
#
# CV mean: 0.6176120939483727
# CV std: 0.011120600655707545
# TEST C-index: 0.6514840733590733
#
# [285/288] k=250 AE=32 CLIN=64
#
# ================ FOLD 1 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5874928557820537
#
# ================ FOLD 2 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6365993249523064
#
# ================ FOLD 3 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6311190499179299
#
# ================ FOLD 4 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5978203466320995
#
# ================ FOLD 5 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6176769387064003
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 250
#
# CV mean: 0.6141417031981579
# CV std: 0.01887655008394128
# TEST C-index: 0.6556467181467182
#
# [286/288] k=250 AE=64 CLIN=16
#
# ================ FOLD 1 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5892550962088017
#
# ================ FOLD 2 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.632343589492736
#
# ================ FOLD 3 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6208844259920826
#
# ================ FOLD 4 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5956598972586298
#
# ================ FOLD 5 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5842484640317352
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 250
#
# CV mean: 0.604478294596797
# CV std: 0.018785056574107954
# TEST C-index: 0.6442446911196911
#
# [287/288] k=250 AE=64 CLIN=32
#
# ================ FOLD 1 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5895884930462946
#
# ================ FOLD 2 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6374798219439417
#
# ================ FOLD 3 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6330018345080621
#
# ================ FOLD 4 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6046857746411254
#
# ================ FOLD 5 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5977940109331914
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 250
#
# CV mean: 0.6125099870145231
# CV std: 0.01921760446635724
# TEST C-index: 0.6170970077220077
#
# [288/288] k=250 AE=64 CLIN=64
#
# ================ FOLD 1 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5864926652695751
#
# ================ FOLD 2 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6260822775522183
#
# ================ FOLD 3 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6378294873032732
#
# ================ FOLD 4 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6163041912717845
#
# ================ FOLD 5 ================
# Selected 250 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5968264718688017
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 250
#
# CV mean: 0.6127070186531306
# CV std: 0.018774236187022907
# TEST C-index: 0.6264780405405406

# %%
results_df.to_csv(here.here(
    "analysis/hyperparameter_seed_search.csv"),
    index=False
)

# %%
best_cv = results_df.loc[
    results_df["cv_mean"].idxmax()
]

print(best_cv)
# Out:
# seed            1.000000
# top_genes      50.000000
# ae_latent      16.000000
# clin_latent    32.000000
# cv_mean         0.665477
# cv_std          0.028677
# test_cindex     0.643269
# Name: 16, dtype: float64

# %%
best_test = results_df.loc[
    results_df["test_cindex"].idxmax()
]

print(best_test)
# Out:
# seed           200.000000
# top_genes       50.000000
# ae_latent        8.000000
# clin_latent     32.000000
# cv_mean          0.648339
# cv_std           0.026658
# test_cindex      0.703487
# Name: 253, dtype: float64

# %%
summary = (
    results_df
    .groupby(
        [
            "top_genes",
            "ae_latent",
            "clin_latent"
        ]
    )
    .agg(
        cv_mean=("cv_mean","mean"),
        cv_std=("cv_mean","std"),
        test_mean=("test_cindex","mean"),
        test_std=("test_cindex","std")
    )
    .reset_index()
)

# %%
summary = summary.sort_values(
    "cv_mean",
    ascending=False
)

print(summary.head(20))
# Out:
#     top_genes  ae_latent  clin_latent   cv_mean    cv_std  test_mean  test_std
# 13         50          8           32  0.648646  0.010098   0.671387  0.021396
# 22         50         64           32  0.645542  0.013408   0.655275  0.013430
# 12         50          8           16  0.645199  0.011779   0.659266  0.008831
# 9          15         64           16  0.645022  0.005688   0.661231  0.019440
# 6          15         32           16  0.644999  0.006885   0.656308  0.022274
# 16         50         16           32  0.644867  0.015150   0.669489  0.020042
# 15         50         16           16  0.643997  0.016515   0.654910  0.017102
# 4          15         16           32  0.643821  0.008043   0.660245  0.030870
# 0          15          8           16  0.642920  0.009192   0.653078  0.021048
# 1          15          8           32  0.642909  0.014857   0.652106  0.027031
# 14         50          8           64  0.642581  0.008037   0.669326  0.016138
# 8          15         32           64  0.642239  0.006318   0.652146  0.018588
# 23         50         64           64  0.642189  0.009937   0.649954  0.015067
# 2          15          8           64  0.641678  0.002860   0.650699  0.017657
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 50
#
# CV mean: 0.6599722760028568
# CV std: 0.02321260765765422
# TEST C-index: 0.6974541505791506
#
# [91/96] k=50 AE=16 CLIN=16
#
# ================ FOLD 1 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6184987616688893
#
# ================ FOLD 2 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6784229320549822
#
# ================ FOLD 3 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6516848508255286
#
# ================ FOLD 4 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6240818090162754
#
# ================ FOLD 5 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6692467708383726
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 50
#
# CV mean: 0.6483870248808097
# CV std: 0.023800051147835257
# TEST C-index: 0.690757722007722
#
# [92/96] k=50 AE=16 CLIN=32
#
# ================ FOLD 1 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6435035244808535
#
# ================ FOLD 2 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6539157657878002
#
# ================ FOLD 3 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6616780921116153
#
# ================ FOLD 4 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6346920159393153
#
# ================ FOLD 5 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6566687630013062
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 50
#
# CV mean: 0.6500916322641782
# CV std: 0.009722962972815665
# TEST C-index: 0.6770632239382239
#
# [93/96] k=75 AE=8 CLIN=16
#
# ================ FOLD 1 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6244999047437607
#
# ================ FOLD 2 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6501981118231179
#
# ================ FOLD 3 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6148015834701168
#
# ================ FOLD 4 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6002688559220318
#
# ================ FOLD 5 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6998210052730879
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 75
#
# CV mean: 0.637917892246423
# CV std: 0.03497043108531076
# TEST C-index: 0.6879524613899614
#
# [94/96] k=75 AE=8 CLIN=32
#
# ================ FOLD 1 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6642693846446942
#
# ================ FOLD 2 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6615956562148413
#
# ================ FOLD 3 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.604325576904509
#
# ================ FOLD 4 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6066541840702866
#
# ================ FOLD 5 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6704561946688598
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 75
#
# CV mean: 0.6414601993006382
# CV std: 0.0295191537321642
# TEST C-index: 0.6798986486486487
#
# [95/96] k=75 AE=16 CLIN=16
#
# ================ FOLD 1 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6347875785863974
#
# ================ FOLD 2 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6145869001614245
#
# ================ FOLD 3 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6189533648739982
#
# ================ FOLD 4 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6001248259638005
#
# ================ FOLD 5 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6694402786512506
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 75
#
# CV mean: 0.6275785896473742
# CV std: 0.02366963525812905
# TEST C-index: 0.6753438706563707
#
# [96/96] k=75 AE=16 CLIN=32
#
# ================ FOLD 1 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'e2f2' 'stat5b' 'gsk3b' 'fancd2' 'stat5a' 'e2f7' 'cdk1' 'bcl2'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6390741093541626
#
# ================ FOLD 2 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'fancd2' 'bcl2' 'cdk1' 'e2f2' 'e2f7' 'chek1' 'stat5b' 'ccne1'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.614342317663748
#
# ================ FOLD 3 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'bcl2' 'stat5b' 'mapt' 'ccne1' 'chek1'
#  'e2f7']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.606063531910785
#
# ================ FOLD 4 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'e2f2' 'gsk3b' 'bcl2' 'fancd2' 'stat5a' 'stat5b' 'mapt' 'tgfbr3'
#  'slc19a1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.5997407460751837
#
# ================ FOLD 5 ================
# Selected 75 genes
# Top genes:
# ['aurka' 'gsk3b' 'fancd2' 'e2f2' 'slc19a1' 'bcl2' 'mapt' 'e2f7' 'aph1b'
#  'ccnb1']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# C-index: 0.6867108509506071
#
# ================ FINAL TRAINING ================
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features
# Top Genes:
# ['aurka' 'fancd2' 'e2f2' 'gsk3b' 'bcl2' 'stat5b' 'mapt' 'e2f7' 'cdk1'
#  'ccnb1']
# Final selected genes: 75
#
# CV mean: 0.6291863111908973
# CV std: 0.03171400194721089
# TEST C-index: 0.6662343146718147

# %%
results_df.to_csv(here.here(
    "analysis/hyperparameter_seed_search_refined.csv"),
    index=False
)

# %%
best_cv = results_df.loc[
    results_df["cv_mean"].idxmax()
]

print(best_cv)
# Out:
# seed            1.000000
# top_genes      25.000000
# ae_latent       8.000000
# clin_latent    16.000000
# cv_mean         0.661793
# cv_std          0.030544
# test_cindex     0.644366
# Name: 4, dtype: float64

# %%
best_test = results_df.loc[
    results_df["test_cindex"].idxmax()
]

print(best_test)
# Out:
# seed           20.000000
# top_genes      75.000000
# ae_latent       8.000000
# clin_latent    16.000000
# cv_mean         0.616298
# cv_std          0.017324
# test_cindex     0.715258
# Name: 44, dtype: float64

# %%
summary = (
    results_df
    .groupby(
        [
            "top_genes",
            "ae_latent",
            "clin_latent"
        ]
    )
    .agg(
        cv_mean=("cv_mean","mean"),
        cv_std=("cv_mean","std"),
        test_mean=("test_cindex","mean"),
        test_std=("test_cindex","std")
    )
    .reset_index()
)

# %%
summary = summary.sort_values(
    "cv_mean",
    ascending=False
)

print(summary.head(20))
# Out:
#     top_genes  ae_latent  clin_latent   cv_mean    cv_std  test_mean  test_std
# 8          50          8           16  0.648933  0.006414   0.657763  0.010951
# 7          25         16           32  0.648720  0.006548   0.654937  0.027225
# 6          25         16           16  0.646460  0.012159   0.659373  0.011032
# 11         50         16           32  0.646454  0.008895   0.660379  0.015836
# 10         50         16           16  0.644844  0.008746   0.661025  0.020789
# 0          15          8           16  0.644077  0.010880   0.651932  0.025121
# 9          50          8           32  0.643467  0.014594   0.663974  0.023045
# 1          15          8           32  0.643249  0.004407   0.647603  0.013978
# 4          25          8           16  0.642416  0.013162   0.655620  0.019878
# 2          15         16           16  0.641987  0.008661   0.652182  0.016189
# 3          15         16           32  0.640801  0.008285   0.649627  0.011745
# 13         75          8           32  0.640751  0.010502   0.662291  0.014932
# 5          25          8           32  0.640689  0.012497   0.650481  0.023962
# 12         75          8           16  0.637854  0.013139   0.676042  0.024728
# 15         75         16           32  0.632986  0.013536   0.654129  0.020830
# 14         75         16           16  0.628229  0.010754   0.657454  0.021063

# %%
summary["robust_score"] = (
    summary["cv_mean"]
    - summary["cv_std"]
)

summary.sort_values(
    "robust_score",
    ascending=False
).head(10)
# Out:
#     top_genes  ae_latent  clin_latent   cv_mean    cv_std  test_mean  \
# 8          50          8           16  0.648933  0.006414   0.657763
# 7          25         16           32  0.648720  0.006548   0.654937
# 1          15          8           32  0.643249  0.004407   0.647603
# 11         50         16           32  0.646454  0.008895   0.660379
# 10         50         16           16  0.644844  0.008746   0.661025
# 6          25         16           16  0.646460  0.012159   0.659373
# 2          15         16           16  0.641987  0.008661   0.652182
# 0          15          8           16  0.644077  0.010880   0.651932
# 3          15         16           32  0.640801  0.008285   0.649627
# 13         75          8           32  0.640751  0.010502   0.662291
#
#     test_std  robust_score
# 8   0.010951      0.642519
# 7   0.027225      0.642172
# 1   0.013978      0.638841
# 11  0.015836      0.637559
# 10  0.020789      0.636098
# 6   0.011032      0.634301
# 2   0.016189      0.633327
# 0   0.025121      0.633197
# 3   0.011745      0.632516
# 13  0.014932      0.630249

# %% [markdown]
# ## Cross-seed and Cross-Validation Results:
# ### The best performing model has:
# - 50 genes
# - Compressed into 8 latent dimensions in the autoencoder
# - Clinical encoder with a final layer of 16 dimensions.

# %%
results_df = run_hyperparameter_search(
    X_clinical,
    mut_frequent,
    expression_data,
    y_time,
    y_event,
    gene_grid=[50],
    ae_grid=[8],
    clin_grid=[16],
    seeds=[1,10,20,50,100,200, 500, 42, 600, 30]
)
# Out:
# ================================================================================
# SEED 1
# ================================================================================
#
# [1/10] k=50 AE=8 CLIN=16
#
# ================ FOLD 1 ================
# Selected 50 genes
# Top genes:
# ['aurka' 'stat5a' 'fancd2' 'e2f2' 'bcl2' 'gsk3b' 'mapt' 'stat5b' 'tubb4b'
#  'diras3']
# [Feature Filter]
# Original: 64 features
# Kept: 64 features
# Dropped: 0 constant features

# %%
results_df.to_csv(here.here(
    "analysis/hyperparameter_seed_search_final.csv"),
    index=False
)

# %%
best_cv = results_df.loc[
    results_df["cv_mean"].idxmax()
]

print(best_cv)
# Out:
# seed            1.000000
# top_genes      25.000000
# ae_latent       8.000000
# clin_latent    16.000000
# cv_mean         0.661793
# cv_std          0.030544
# test_cindex     0.644366
# Name: 4, dtype: float64

# %%
best_test = results_df.loc[
    results_df["test_cindex"].idxmax()
]

print(best_test)
# Out:
# seed           20.000000
# top_genes      75.000000
# ae_latent       8.000000
# clin_latent    16.000000
# cv_mean         0.616298
# cv_std          0.017324
# test_cindex     0.715258
# Name: 44, dtype: float64

# %%
summary = (
    results_df
    .groupby(
        [
            "top_genes",
            "ae_latent",
            "clin_latent"
        ]
    )
    .agg(
        cv_mean=("cv_mean","mean"),
        cv_std=("cv_mean","std"),
        test_mean=("test_cindex","mean"),
        test_std=("test_cindex","std")
    )
    .reset_index()
)

# %%
summary = summary.sort_values(
    "cv_mean",
    ascending=False
)

print(summary.head(20))
# Out:
#     top_genes  ae_latent  clin_latent   cv_mean    cv_std  test_mean  test_std
# 8          50          8           16  0.648933  0.006414   0.657763  0.010951
# 7          25         16           32  0.648720  0.006548   0.654937  0.027225
# 6          25         16           16  0.646460  0.012159   0.659373  0.011032
# 11         50         16           32  0.646454  0.008895   0.660379  0.015836
# 10         50         16           16  0.644844  0.008746   0.661025  0.020789
# 0          15          8           16  0.644077  0.010880   0.651932  0.025121
# 9          50          8           32  0.643467  0.014594   0.663974  0.023045
# 1          15          8           32  0.643249  0.004407   0.647603  0.013978
# 4          25          8           16  0.642416  0.013162   0.655620  0.019878
# 2          15         16           16  0.641987  0.008661   0.652182  0.016189
# 3          15         16           32  0.640801  0.008285   0.649627  0.011745
# 13         75          8           32  0.640751  0.010502   0.662291  0.014932
# 5          25          8           32  0.640689  0.012497   0.650481  0.023962
# 12         75          8           16  0.637854  0.013139   0.676042  0.024728
# 15         75         16           32  0.632986  0.013536   0.654129  0.020830
# 14         75         16           16  0.628229  0.010754   0.657454  0.021063

# %%
summary["robust_score"] = (
    summary["cv_mean"]
    - summary["cv_std"]
)

summary.sort_values(
    "robust_score",
    ascending=False
).head(10)
# Out:
#     top_genes  ae_latent  clin_latent   cv_mean    cv_std  test_mean  \
# 8          50          8           16  0.648933  0.006414   0.657763
# 7          25         16           32  0.648720  0.006548   0.654937
# 1          15          8           32  0.643249  0.004407   0.647603
# 11         50         16           32  0.646454  0.008895   0.660379
# 10         50         16           16  0.644844  0.008746   0.661025
# 6          25         16           16  0.646460  0.012159   0.659373
# 2          15         16           16  0.641987  0.008661   0.652182
# 0          15          8           16  0.644077  0.010880   0.651932
# 3          15         16           32  0.640801  0.008285   0.649627
# 13         75          8           32  0.640751  0.010502   0.662291
#
#     test_std  robust_score
# 8   0.010951      0.642519
# 7   0.027225      0.642172
# 1   0.013978      0.638841
# 11  0.015836      0.637559
# 10  0.020789      0.636098
# 6   0.011032      0.634301
# 2   0.016189      0.633327
# 0   0.025121      0.633197
# 3   0.011745      0.632516
# 13  0.014932      0.630249
